# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Extraindo o data set
df = pd.read_csv('dataBases/cat_breeds.csv', sep=';')
df
# Out:
#            Breed  Age_in_years  Age_in_months  ... Country   Latitude  Longitude
# 0         Angora          0.25              3  ...  France  43.296482   5.369780
# 1         Angora          0.33              4  ...  France  43.611660   3.877710
# 2         Angora          0.50              6  ...  France  44.837789  -0.579180
# 3         Angora          0.50              6  ...  France  43.611660   3.877710
# 4         Angora          0.50              6  ...  France  48.864716   2.349014
# ...          ...           ...            ...  ...     ...        ...        ...
# 1066  Maine coon          0.17              2  ...      UK  51.507351  -0.127758
# 1067  Maine coon          0.17              2  ...      UK  51.507351  -0.127758
# 1068  Maine coon          0.17              2  ...      UK  51.507351  -0.127758
# 1069  Maine coon          0.17              2  ...      UK  52.486244  -1.890401
# 1070  Maine coon          0.17              2  ...      UK  51.507351  -0.127758
#
# ...

# %%
df.columns
# Out:
# Index(['Breed', 'Age_in_years', 'Age_in_months', 'Gender',
#        'Neutered_or_spayed', 'Body_length', 'Weight', 'Fur_colour_dominant',
#        'Fur_pattern', 'Eye_colour', 'Allowed_outdoor', 'Preferred_food',
#        'Owner_play_time_minutes', 'Sleep_time_hours', 'Country', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
features = ['Gender', 'Body_length', 'Fur_colour_dominant', 'Fur_pattern', 'Eye_colour', 'Country']
target = 'Breed'


df_features = df[features].copy()
s_target = df[target].copy()

# %%
from sklearn.preprocessing import LabelEncoder

le_feature = {}
df_le = df_features.copy()
for feat in features:
    if df_features[feat].dtype == 'object':
        df_features[feat] = LabelEncoder()
        df_le[feat] = df_features[feat].fit_transform(df_le[feat])

le_target = s_target.copy()
if le_target.dtype == 'object':
    target_le = LabelEncoder()
    le_target = target_le.fit_transform(le_target)

le_target = pd.Series(le_target, name=target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15420\124703797.py in ?()
#       4 df_le = df_features.copy()
#       5 for feat in features:
#       6     if df_features[feat].dtype == 'object':
#       7         df_features[feat] = LabelEncoder()
# ----> 8         df_le[feat] = df_features[feat].fit_transform(df_le[feat])
#       9
#      10 le_target = s_target.copy()
#      11 if (le_target.dtype == 'object'):
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'fit_transform'
